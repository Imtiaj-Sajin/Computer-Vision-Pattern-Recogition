# %% [markdown]
# <a href="https://colab.research.google.com/github/Imtiaj-Sajin/Computer-Vision-Pattern-Recogition/blob/main/matplotlib_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[2,9,2,98,4]

plt.plot(x,y)

# %%
plt.xlabel('Day')
plt.ylabel('Temp')
plt.title('Weather')
plt.plot(x,y)

# %%
plt.plot(x,y, color='green')

# %%
plt.plot(x,y,color='magenta',linewidth='4')

# %%
plt.plot(x,y,color='red',linewidth='1',marker='+')

# %%
plt.plot(x,y,color='red',linewidth='1',marker='+',linestyle=':')

# %%
plt.plot(x,y,'b+--') #blue marker='+' linestyle='--' dashed line

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='',markersize=20)

# %%
plt.plot(x,y,'g*',alpha=0.5) #g=green color,marker=*, alpha=scale

# %% [markdown]
# # **figure()**

# %%
import numpy as np
y1=np.sin(x)
y2=np.cos(x)

# %%
plt.figure()
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(('sin','cos'))
plt.show()

# %%
x=np.arange(-10,10,.01)
y1=np.sin(x)
y2=np.cos(x)

plt.figure()
plt.plot(x,y1,x,y2)
plt.legend(['sin','cos'])
plt.show()

# %% [markdown]
# # **Subplot**

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1) #1,2,1 mean 1 row, 2 columns, and this is the first subplot.
plt.plot(x,y1)
plt.title('Sine')

plt.subplot(1,2,2) #1,2,2 mean 1 row, 2 columns, and this is the second subplot.
plt.plot(x,y2)
plt.title('Cosine')

plt.show()

# %% [markdown]
# # **Live animation of sine wave**

# %%
from IPython.display import display

sin =[]
X = []

plt.figure()
for i in range(-50,50,1):
    X.append(i)
    sin.append(np.sin(i))
    display.clear_output(wait=True)
    plt.plot(X,sin)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-a4eb2199a196> in <cell line: 7>()
#       8     X.append(i)
#       9     sin.append(np.sin(i))
# ---> 10     display.clear_output(wait=True)
#      11     plt.plot(X,sin)
#      12     plt.show()
#
# AttributeError: 'function' object has no attribute 'clear_output'

# %%
#live animation of sine wave
from IPython.display import clear_output

sin =[]
X = []
cos=[]

plt.figure(figsize=(15, 10))
for i in range(-50,50,1):
    X.append(i)
    sin.append(np.sin(i))
    #cos.append(np.cos(i))
    clear_output(wait=True)
    plt.plot(X,sin)
    #plt.plot(X,cos)
    plt.show()

# %% [markdown]
# # Save Figure

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,1,1)
plt.plot(x,y1)
plt.legend(['Sine'])

plt.subplot(2,1,2)
plt.plot(x,y2,color='red')
plt.legend(['Cosine'])
plt.show()
